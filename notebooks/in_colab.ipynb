# %% [markdown]
# To run code on google colab you'll first need to clone the repo and checkout the development branch

# %% [markdown]
# !git clone https://github.com/cjblack/climbing-analysis.git
# %cd climbing-analysis
# !git fetch
# !git checkout development

# %% [markdown]
# Then you'll need to install microconda and create the climbing-analysis environment

# %%
# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# !./bin/micromamba create -y -n climbing-analysis -f environment.yml
# !eval "$(./bin/micromamba shell hook -s bash)" && micromamba activate climbing-analysis

# %%
# !pip install open-ephys-python-tools spikeinterface scikit-learn

# %% [markdown]
# Install pip packages as microconda will skip this step when creating the conda environment from the yaml file

# %%
# !pip install open-ephys-python-tools spikeinterface scikit-learn
# !pip install -q gdown
